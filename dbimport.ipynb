# %%
import pandas as pd
from flask import Flask, render_template
import os # importing operating system module
import pymongo as pymongo

# %%
mongoDB_uri = 'mongodb+srv://May:aoawBkhm2ZqVX7EC@spotify.olfe9td.mongodb.net/?retryWrites=true&w=majority'

# %%
client = pymongo.MongoClient(mongoDB_uri)
db = client.spotify

# %%
songs = []

# %%
class Song:
    def __init__(self, total_streams, artist, title, country):
        self.total_streams = total_streams
        self.artist = artist
        self.title = title
        self.country = country

# %%
df = pd.read_csv('top_200_songs_by_country.csv')
df
# Out:
#        Pos   P+                                   Artist and Title    Days  \
# 0        1   +2                    Benson Boone - Beautiful Things    22.0
# 1        2    =                                   Xavi - La Diabla    64.0
# 2        3   -2                                Tate McRae - greedy   148.0
# 3        4    =  The Weeknd - One Of The Girls (w/ JENNIE, Lily...   125.0
# 4        5    =                        Taylor Swift - Cruel Summer   369.0
# ...    ...  ...                                                ...     ...
# 14746  196  -19                                 Táo - Blue Tequila  1218.0
# 14747  197   +1                           Sean - Em Thích (w/ Lửa)   388.0
# 14748  198  -15                          AMEE - đen đá không đường    61.0
# 14749  199   -6                                Vũ. - Bước Qua Nhau   767.0
# 14750  200   RE                      Winno - Say Đắm Trong Lần Đầu   198.0
#
# ...

# %%
for i in range(len(df)):
    row = df.iloc[i]
    row_list = row.tolist()
    para_list = row_list[12:]
    song_object = Song(*para_list)
    song_dict = vars(song_object)
    songs.append(song_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       3 row_list = row.tolist()
#       4 para_list = row_list[12:]
# ----> 5 song_object = Song(*para_list)
#       6 song_dict = vars(song_object)
#       7 songs.append(song_dict)
#
# TypeError: Song.__init__() missing 2 required positional arguments: 'title' and 'country'

# %%
for song in songs:
    db.songs.insert_one(song)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 for song in songs:
# ----> 2     db.songs.insert_one(song)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# ...

# %%
print(client.list_database_names())

# %%
app = Flask(__name__)
if __name__ == '__main__':
    # for deployment we use the environ
    # to make it work for both production and development
    port = int(os.environ.get("PORT", 5000))
    app.run(debug=True, host='0.0.0.0', port=port)
