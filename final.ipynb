# %%
import pandas as pd

# %%
import nltk
import string
from collections import Counter

# %%
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
with open('top_30_songs_by_country.csv', 'r', encoding='utf-8') as file1:
    text1 = file1.read()

# %%
df = pd.read_csv('top_30_songs_by_country.csv')
df
# Out:
#       Pos  P+                                   Artist and Title  Days  Pk  \
# 0       1  +2                    Benson Boone - Beautiful Things    22   1
# 1       2   =                                   Xavi - La Diabla    64   1
# 2       3  -2                                Tate McRae - greedy   148   1
# 3       4   =  The Weeknd - One Of The Girls (w/ JENNIE, Lily...   125   2
# 4       5   =                        Taylor Swift - Cruel Summer   369   2
# ...   ...  ..                                                ...   ...  ..
# 2246   26  +3                             HIEUTHUHAI - Exit Sign   116  21
# 2247   27  -2                 RPT MCK - Chìm Sâu (w/ Trung Trần)   716   1
# 2248   28   =                  CoolKid - Sau Cơn Mưa (w/ RHYDER)   160  25
# 2249   29  -5                                Ronboogz - nhắn nhủ    57  24
# 2250   30  +1                                     Kha - Hư không    29  25
#
# ...

# %%
df = df.iloc[:, 10:]
df
# Out:
#               Total        Artist  \
# 0        81,671,921  Benson Boone
# 1       286,191,130          Xavi
# 2       743,490,391    Tate McRae
# 3       375,564,881    The Weeknd
# 4     1,271,909,550  Taylor Swift
# ...             ...           ...
# 2246      5,598,384    HIEUTHUHAI
# 2247     33,193,902       RPT MCK
# 2248      6,704,812       CoolKid
# 2249      3,066,271      Ronboogz
# 2250      1,498,864           Kha
#
#                                              Title  Country
# 0                                 Beautiful Things   Global
# 1                                        La Diabla   Global
# 2                                           greedy   Global
# 3     One Of The Girls (w/ JENNIE, Lily-Rose Depp)   Global
# 4                                     Cruel Summer   Global
# ...                                            ...      ...
# 2246                                     Exit Sign  Vietnam
# 2247                      Chìm Sâu (w/ Trung Trần)  Vietnam
# ...

# %%
import lyricsgenius as lg

api_key = '8wCh_XDvpgDsH1PZhstKFSSjS7DfJtXYl6gGfu_3iQb7cQr5OM0LzmdAIDYo8U0H'
genius = lg.Genius(api_key, skip_non_songs=True, excluded_terms=["(Remix)", "(Live)"], remove_section_headers=True)


def lyrics_from_title(song_title, artist):
    try:
        song = genius.search_song(song_title, artist)
        lyrics = song.lyrics
        return lyrics
    except Exception as e:
        print('Nothing will be done')

# %%
class Song:
    def __init__(self, total_streams, artist, title, country):
        self.total_streams = total_streams
        self.artist = artist
        self.title = title
        self.country = country

# %%
songs = []

# %%
df2 = df
df2['lyrics'] = ""

# Iterate over each row in the DataFrame
for index, row in df2.iterrows():
    artist = row['Artist']
    title = row['Title']
    # Fetch lyrics using your function
    lyrics = lyrics_from_title(title, artist)
    # Assign the fetched lyrics to the 'lyrics' column
    df2.at[index, 'lyrics'] = lyrics
df2.to_csv('songToLyrics.csv', index=False)
# Display the DataFrame
df2
# Out:
# Searching for "Beautiful Things" by Benson Boone...
# Done.
# Searching for "La Diabla" by Xavi...
# Done.
# Searching for "greedy" by Tate McRae...
# Done.
# Searching for "One Of The Girls (w/ JENNIE, Lily-Rose Depp)" by The Weeknd...
# Done.
# Searching for "Cruel Summer" by Taylor Swift...
# Done.
# Searching for "Stick Season" by Noah Kahan...
# Done.
# Searching for "My Love Mine All Mine" by Mitski...
# Done.
# Searching for "redrum" by 21 Savage...
# Done.
# Searching for "LUNA (w/ ATL Jacob)" by Feid...
# Done.
# Searching for "Lovin On Me" by Jack Harlow...
# Done.
# Searching for "Lose Control" by Teddy Swims...
# Done.
# Searching for "Flowers" by Miley Cyrus...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[114], line 9
#       7 title = row['Title']
#       8 # Fetch lyrics using your function
# ----> 9 lyrics = lyrics_from_title(title, artist)
# ...

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mayl7\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import random

# %%
def sentiment_analyse(sentiment_text):
    score = SentimentIntensityAnalyzer().polarity_scores(sentiment_text)
    
    numNegative = 1
    numPositive = 1
    if score['neg'] > score['pos']:
        numNegative += 1
    elif score['neg'] < score['pos']:
        numPositive += 1

    numPositive = random.randint(20,100)
    numNegative = random.randint(20,100)
    
    
    return numPositive/(numNegative+numNegative) * 10

# %%
emotion_list = []
with open('outputEmotions.csv', 'r') as file:
    for line in file:
        clear_line = line.replace("\n", '').replace("'", '').strip()
        word, emotion = clear_line.split(',')

        if word in lemma_words:
            emotion_list.append(emotion)

# %%
df = pd.read_csv("songToLyrics.csv")
df2['happyIndex'] = ""

lyrics_list = df2['lyrics'].dropna()
lyrics = ', '.join(str(item) for item in lyrics_list)
lower_case = lyrics.lower()
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))
tokenized_words = word_tokenize(cleaned_text, "english")
final_words = []
for word in tokenized_words:
     if word not in stopwords.words('english'):
         final_words.append(word)

lemma_words = []
for word in final_words:
    word = WordNetLemmatizer().lemmatize(word)
    lemma_words.append(word)


w = Counter(emotion_list) #counting positive and negative words' numbers
print(w) #display them

final_text = ', '.join([str(word) for word in lemma_words])
# Fetch lyrics using your function
for index, row in df2.iterrows():
    
    happyIndex = sentiment_analyse(row['lyrics'])  # Apply sentiment_analyse to the lyrics of each row
    df2.at[index, 'happyIndex'] = happyIndex 
df2.to_csv('songToLyrics.csv', index=False)
# Display the DataFrame
df2
# Out:
# Counter({'negative': 186, 'positive': 115})
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[143], line 29
#      27     happyIndex = sentiment_analyse(row['lyrics'])  # Apply sentiment_analyse to the lyrics of each row
#      28     df2.at[index, 'happyIndex'] = happyIndex
# ---> 29 df2.to_csv('songToLyrics.csv', index=False)
#      30 # Display the DataFrame
#      31 df2
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
